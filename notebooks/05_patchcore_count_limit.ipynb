# %% [markdown]
# # Demo 05: PatchCore Count Limit
#
# This notebook focuses on the counting and semantics boundary in the synthetic limits lab.

# %%
from pathlib import Path

from xai_demo_suite.reports.patchcore_limits import (
    PatchCoreLimitsReportConfig,
    build_patchcore_limits_report,
)

# %%
config = PatchCoreLimitsReportConfig(output_dir=Path("outputs/patchcore_limits"))
build_patchcore_limits_report(config)
