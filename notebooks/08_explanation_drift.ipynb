# %% [markdown]
# # Demo 08: Explanation Drift Under Shift
#
# This notebook compares metric drift and explanation drift for the shortcut-sensitive classifier path and any prepared anomaly-drift sections.

# %%
from pathlib import Path

from xai_demo_suite.reports.explanation_drift import (
    ExplanationDriftReportConfig,
    build_explanation_drift_report,
)

# %%
config = ExplanationDriftReportConfig(
    output_dir=Path("outputs/explanation_drift"),
    industrial_manifest_path=Path("data/processed/neu_cls/shortcut_binary/manifest.jsonl"),
)
build_explanation_drift_report(config)
