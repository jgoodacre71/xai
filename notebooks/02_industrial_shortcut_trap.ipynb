# %% [markdown]
# # Demo 02: Industrial Shortcut Trap
#
# This notebook compares the shortcut-correlated baseline against the stamp-reduced intervention on either the synthetic fallback or a prepared real-image NEU-CLS shortcut split.

# %%
from pathlib import Path

from xai_demo_suite.reports.shortcut_industrial import (
    IndustrialShortcutReportConfig,
    build_industrial_shortcut_report,
)

# %%
config = IndustrialShortcutReportConfig(
    output_dir=Path("outputs/shortcut_industrial"),
    real_manifest_path=Path("data/processed/neu_cls/shortcut_binary/manifest.jsonl"),
)
build_industrial_shortcut_report(config)
