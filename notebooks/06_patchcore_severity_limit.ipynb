# %% [markdown]
# # Demo 06: PatchCore Severity Mismatch
#
# This notebook shows why feature-space anomaly score and engineering severity are different quantities.

# %%
from pathlib import Path

from xai_demo_suite.reports.patchcore_severity import (
    PatchCoreSeverityReportConfig,
    build_patchcore_severity_report,
)

# %%
config = PatchCoreSeverityReportConfig(output_dir=Path("outputs/patchcore_severity"))
build_patchcore_severity_report(config)
