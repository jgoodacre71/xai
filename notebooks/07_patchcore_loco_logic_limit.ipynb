# %% [markdown]
# # Demo 07: PatchCore LOCO Logic Limit
#
# This notebook contrasts PatchCore patch novelty against a narrow component-aware rule on MVTec LOCO AD.

# %%
from pathlib import Path

from xai_demo_suite.reports.patchcore_logic import (
    PatchCoreLogicReportConfig,
    build_patchcore_logic_report,
)

# %%
config = PatchCoreLogicReportConfig(
    output_dir=Path("outputs/patchcore_logic"),
    manifest_path=Path("data/processed/mvtec_loco_ad/juice_bottle/manifest.jsonl"),
)
build_patchcore_logic_report(config)
