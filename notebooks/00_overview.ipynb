# %% [markdown]
# # XAI Demo Suite Overview
#
# This notebook is the top-level walkthrough for the curated demo suite. Package code in `src/xai_demo_suite/` remains the product; the notebook layer is the showroom.

# %% [markdown]
# ## Demo map
#
# 1. Waterbirds shortcut learning
# 2. Industrial shortcut trap
# 3. PatchCore on MVTec AD bottle
# 4. PatchCore learns the wrong normal
# 5. PatchCore count limits
# 6. PatchCore severity mismatch
# 7. PatchCore logical anomaly limits
# 8. Explanation drift under shift
#
# Open `outputs/index.html` after rebuilding the suite for the strongest local presentation flow.
