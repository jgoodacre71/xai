# %% [markdown]
# # Demo 01: Waterbirds Shortcut
#
# ## Learning goals
# - compare average accuracy with worst-group accuracy;
# - inspect Grad-CAM and Integrated Gradients on crossed-group cases;
# - contrast ERM with group-balanced training on the same benchmark slice.

# %%
from pathlib import Path

from xai_demo_suite.reports.waterbirds_shortcut import (
    WaterbirdsShortcutReportConfig,
    build_waterbirds_shortcut_report,
)

# %%
config = WaterbirdsShortcutReportConfig(
    output_dir=Path("outputs/waterbirds_shortcut"),
    manifest_path=Path("data/processed/waterbirds/waterbird_complete95_forest2water2/manifest.jsonl"),
)
build_waterbirds_shortcut_report(config)

# %% [markdown]
# ## What to inspect
#
# Open `outputs/waterbirds_shortcut/index.html`. Follow the metric summary, crossed-group explanation panels, perturbation diagnostics, and prototype exemplars in order.
