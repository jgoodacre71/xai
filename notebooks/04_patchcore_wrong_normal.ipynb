# %% [markdown]
# # Demo 04: PatchCore Learns the Wrong Normal
#
# This notebook shows how nuisance contamination inside the nominal set changes the memory bank and the explanation path.

# %%
from pathlib import Path

from xai_demo_suite.reports.patchcore_wrong_normal import (
    PatchCoreWrongNormalReportConfig,
    build_patchcore_wrong_normal_report,
)

# %%
config = PatchCoreWrongNormalReportConfig(output_dir=Path("outputs/patchcore_wrong_normal"))
build_patchcore_wrong_normal_report(config)
